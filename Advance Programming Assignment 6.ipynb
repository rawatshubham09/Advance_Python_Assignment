# %% [markdown]
# # Assignment 6

# %% [markdown]
# - 1. You are given two strings s and t. String t is generated by randomly shuffling string s and then adding one more letter at a random position. Return the letter that was added to t.

# %%
def find_the_difference(st1, st2):
    li,new_li = list(st1),[]
    for i in st2:
        if i not in li:
            new_li.append(i)
        else:
            li.remove(i)
    return new_li

# %%
test = [["abcd", "abcde"], ["", "y"], ["ae", "aea"], ["abcdefg", "abcdefghigh"]]

for st1,st2 in test:
    print(st1,st2, "-->", *find_the_difference(st1,st2))
# Out:
# abcd abcde --> e
#  y --> y
# ae aea --> a
# abcdefg abcdefghigh --> h i g h

# %% [markdown]
# - 2. Given a function that accepts unlimited arguments, check and count how many data types are in those arguments. Finally return the total in a list.

# %%
def count_datatypes(*args):
    """This function take number of arguments and return its data type count"""
    val = {'int':0, 'str':0, 'bool':0, 'list':0, 'tuple':0, 'dict':0}
    for i in args:
        a = str(type(i))[8:-2]
        val[a] += 1
    ans = list(val.values())
    return ans

# %%
print("1, 45, Hi, False  : ",count_datatypes(1, 45, "Hi", False))
print("[10, 20], (t, Ok), 2, 3, 1   : ", count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1))
print(count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1, 3], {"Brayan": 18}, 25, 23))
print(count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6]))
# Out:
# 1, 45, Hi, False  :  [2, 1, 1, 0, 0, 0]
# [10, 20], (t, Ok), 2, 3, 1   :  [3, 0, 0, 1, 1, 0]
# [2, 2, 3, 1, 0, 2]
# [2, 0, 1, 2, 2, 0]

# %% [markdown]
# - 3. A Fibonacci string is a precedence of the Fibonacci series. It works with any two characters of the English alphabet (as opposed to the numbers 0 and 1 in the Fibonacci series) as the initial items and concatenates them together as it progresses in a similar fashion as the Fibonacci series.

# %%
def fib_str(num, lis):
    new_lis= lis.copy()
    val = ""
    for i in range(num):
        val = new_lis[i + 1] + new_lis[i]
        new_lis.append(val)
    return new_lis

# %%
test = [[8,['a','b']], [5, ['g', 'h']], [6, ['i', 'j']]]
for num, lis in test:
    print(num,"Times", *lis, "fib_series :- ", *fib_str(num,lis))
# Out:
# 8 Times a b fib_series :-  a b ba bab babba babbabab babbababbabba babbababbabbababbabab babbababbabbababbababbabbababbabba babbababbabbababbababbabbababbabbababbababbabbababbabab
# 5 Times g h fib_series :-  g h hg hgh hghhg hghhghgh hghhghghhghhg
# 6 Times i j fib_series :-  i j ji jij jijji jijjijij jijjijijjijji jijjijijjijjijijjijij

# %% [markdown]
# - 4. Given an integer between 0 and 26, make a variable (self.answer). That variable would be assigned to a string in this format:
#
#     "nines:your answer, threes:your answer, ones:your answer"
#
#     You need to find out how many ones, threes, and nines it would at least take for the number of each to add up to the given integer when multiplied by one, three or nine (depends).

# %%
def ones_threes_nines(num):
    a=b=c=0
    while num>0:
        if num>=9: a += 1; num -= 9
        elif num>=3: b += 1; num -= 3
        elif num>=1: c += 1; num -= 1 
    return "nines:"+ str(a) +", threes:"+ str(b) +", ones:"+ str(c)

# %%
numbers = [0,5,10,15,20,25]
for num in numbers:
    print(num, "--->", ones_threes_nines(num))
# Out:
# 0 ---> nines:0, threes:0, ones:0
# 5 ---> nines:0, threes:1, ones:2
# 10 ---> nines:1, threes:0, ones:1
# 15 ---> nines:1, threes:2, ones:0
# 20 ---> nines:2, threes:0, ones:2
# 25 ---> nines:2, threes:2, ones:1

# %% [markdown]
# - 5. The Fibonacci sequence is a classic use case for recursive functions since the value of the sequence at a given index is dependent on the sum of the last two values. However, the recursion tree created by solving the Fibonacci sequence recursively can grow quite fast. Therefore it can be important to think about the implications of running a function recursively. Depending on the size of n needed and the capabilities of the system in question you might want to take a different approach.
#
#     Write a non-recursive function that takes an integer n and returns the Fibonacci sequence's value at index n.

# %%
def fib(num):
    a,b = 0,1
    val= new = 0
    for i in range(2,num):
        val = b
        b = a + b
        a = val
        new = a + b
    return 1 if num in [1,2] else new

# %%
number = [1,4,6,10,11,15,20]
for num in number:
    print(num, "---->", fib(num))
# Out:
# 1 ----> 1
# 4 ----> 3
# 6 ----> 8
# 10 ----> 55
# 11 ----> 89
# 15 ----> 610
# 20 ----> 6765
